# %%
import pandas as pd

# %%
data=pd.read_csv('ecom_data.csv',index_col=None)
data.head()
# Out:
#    Unnamed: 0 InvoiceNo StockCode                          Description  \
# 0           0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER
# 1           1    536365     71053                  WHITE METAL LANTERN
# 2           2    536365    84406B       CREAM CUPID HEARTS COAT HANGER
# 3           3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE
# 4           4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.
#
#    Quantity     InvoiceDate  UnitPrice  CustomerID         Country
# 0         6  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1         6  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2         8  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3         6  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4         6  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
data.drop("Unnamed: 0",inplace=True,axis=1)
data.shape
# Out:
# (541909, 8)

# %%
data.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
data.Country.unique()
# Out:
# array(['United Kingdom', 'France', 'Australia', 'Netherlands', 'Germany',
#        'Norway', 'EIRE', 'Switzerland', 'Spain', 'Poland', 'Portugal',
#        'Italy', 'Belgium', 'Lithuania', 'Japan', 'Iceland',
#        'Channel Islands', 'Denmark', 'Cyprus', 'Sweden', 'Austria',
#        'Israel', 'Finland', 'Bahrain', 'Greece', 'Hong Kong', 'Singapore',
#        'Lebanon', 'United Arab Emirates', 'Saudi Arabia',
#        'Czech Republic', 'Canada', 'Unspecified', 'Brazil', 'USA',
#        'European Community', 'Malta', 'RSA'], dtype=object)

# %%
data.Country.value_counts()
# Out:
# Country
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
data.drop_duplicates()
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# ...

# %%
data.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
data.shape
# Out:
# (541909, 8)

# %%
gp=data.groupby(['Country','InvoiceNo'],as_index=True)
gp.first()
# Out:
#                       StockCode                          Description  \
# Country     InvoiceNo
# Australia   536389        22941         CHRISTMAS LIGHTS 10 REINDEER
#             537676        22567              20 DOLLY PEGS RETROSPOT
#             539419        48138                   DOORMAT UNION FLAG
#             540267        22078             RIBBON REEL LACE DESIGN
#             540280        21422                 PORCELAIN ROSE SMALL
# ...                         ...                                  ...
# Unspecified 563947        23236           STORAGE TIN VINTAGE DOILY
#             564051        23355           HOT WATER BOTTLE KEEP CALM
#             565303        22904            CALENDAR PAPER CUT DESIGN
#             576646        22326  ROUND SNACK BOXES SET OF4 WOODLAND
#             578539        22150             3 STRIPEY MICE FELTCRAFT
#
#                        Quantity       InvoiceDate  UnitPrice  CustomerID
# Country     InvoiceNo
# ...

# %%
gp.get_group(('Australia','540267')).sort_values('Quantity',ascending=False)
# Out:
#       InvoiceNo StockCode                         Description  Quantity  \
# 45536    540267     22492             MINI PAINT SET VINTAGE        576
# 45534    540267     21915              RED  HARMONICA IN BOX        240
# 45541    540267     22720   SET OF 3 CAKE TINS PANTRY DESIGN        240
# 45535    540267     21914              BLUE HARMONICA IN BOX        240
# 45522    540267     22522            CHILDS GARDEN FORK BLUE        192
# 45542    540267     22722   SET OF 6 SPICE TINS PANTRY DESIGN       168
# 45539    540267     22620         4 TRADITIONAL SPINNING TOPS       160
# 45514    540267     22077              6 RIBBONS RUSTIC CHARM       144
# 45538    540267     21891    TRADITIONAL WOODEN SKIPPING ROPE       144
# 45530    540267     22857           ASSORTED EASTER GIFT TAGS       144
# 45528    540267     84228          HEN HOUSE W CHICK STANDING       120
# 45512    540267     22079          RIBBON REEL HEARTS DESIGN        120
# ...

# %%
data.groupby(['Country'],as_index=False,sort=True).sum("Quantity")
# Out:
#                  Country  Quantity    UnitPrice    CustomerID
# 0              Australia     83653     4054.750  1.569300e+07
# 1                Austria      4827     1701.520  5.021102e+06
# 2                Bahrain       260       86.570  2.100270e+05
# 3                Belgium     23152     7540.130  2.571829e+07
# 4                 Brazil       356      142.600  4.086080e+05
# 5                 Canada      2763      910.580  2.615483e+06
# 6        Channel Islands      9479     3738.550  1.128522e+07
# 7                 Cyprus      6317     3920.070  7.715880e+06
# 8         Czech Republic       592       88.150  3.834300e+05
# 9                Denmark      8188     1266.950  4.876734e+06
# 10                  EIRE    142637    48447.190  1.103917e+08
# 11    European Community       497      294.050  9.215880e+05
# 12               Finland     10666     3786.850  8.699324e+06
# 13                France    110480    43031.990  1.076489e+08
# ...

# %%
gp.groups
# Out:
# {('Australia', '536389'): [197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209, 210], ('Australia', '537676'): [17067, 17068, 17069, 17070, 17071, 17072, 17073, 17074], ('Australia', '539419'): [34673, 34674, 34675, 34676, 34677, 34678, 34679, 34680, 34681, 34682], ('Australia', '540267'): [45511, 45512, 45513, 45514, 45515, 45516, 45517, 45518, 45519, 45520, 45521, 45522, 45523, 45524, 45525, 45526, 45527, 45528, 45529, 45530, 45531, 45532, 45533, 45534, 45535, 45536, 45537, 45538, 45539, 45540, 45541, 45542, 45543, 45544, 45545, 45546, 45547, 45548, 45549, 45550, 45551, 45552, 45553, 45554, 45555, 45556], ('Australia', '540280'): [45824, 45825], ('Australia', '540557'): [50805], ('Australia', '540700'): [52263, 52264, 52265, 52266, 52267, 52268, 52269, 52270, 52271, 52272, 52273, 52274, 52275, 52276, 52277, 52278, 52279, 52280, 52281], ('Australia', '541149'): [57298, 57299, 57300], ('Australia', '541271'): [59113, 59114, 59115, 59116, 59117, 59118, 59119, 59120, 59121,
# ...

# %%
gp.ngroups
# Out:
# 25900

# %%
gp.indices
# Out:
# {('Australia',
#   '536389'): array([197, 198, 199, 200, 201, 202, 203, 204, 205, 206, 207, 208, 209,
#         210], dtype=int64),
#  ('Australia',
#   '537676'): array([17067, 17068, 17069, 17070, 17071, 17072, 17073, 17074],
#        dtype=int64),
#  ('Australia',
#   '539419'): array([34673, 34674, 34675, 34676, 34677, 34678, 34679, 34680, 34681,
#         34682], dtype=int64),
#  ('Australia',
#   '540267'): array([45511, 45512, 45513, 45514, 45515, 45516, 45517, 45518, 45519,
#         45520, 45521, 45522, 45523, 45524, 45525, 45526, 45527, 45528,
#         45529, 45530, 45531, 45532, 45533, 45534, 45535, 45536, 45537,
#         45538, 45539, 45540, 45541, 45542, 45543, 45544, 45545, 45546,
#         45547, 45548, 45549, 45550, 45551, 45552, 45553, 45554, 45555,
#         45556], dtype=int64),
#  ('Australia', '540280'): array([45824, 45825], dtype=int64),
#  ('Australia', '540557'): array([50805], dtype=int64),
#  ('Australia',
# ...

# %%
for name,group in gp.groups:
    print(name)
    print(group)
# Out:
# Australia
# 536389
# Australia
# 537676
# Australia
# 539419
# Australia
# 540267
# Australia
# 540280
# Australia
# 540557
# Australia
# 540700
# Australia
# 541149
# Australia
# 541271
# Australia
# 541520
# Australia
# 541657
# Australia
# 542542
# Australia
# 543357
# Australia
# 543372
# Australia
# 543376
# Australia
# 543989
# Australia
# 545065
# Australia
# 545475
# Australia
# 546135
# Australia
# 547659
# Australia
# 548661
# Australia
# 549313
# Australia
# 552956
# Australia
# 553546
# Australia
# 554037
# Australia
# 554126
# Australia
# 556917
# Australia
# 556918
# Australia
# 558536
# Australia
# 558537
# Australia
# 559919
# Australia
# 559920
# Australia
# 560033
# Australia
# 560473
# Australia
# 560491
# Australia
# 561040
# Australia
# 561228
# Australia
# 563179
# Australia
# 563614
# Australia
# 565145
# Australia
# 565146
# Australia
# 565466
# Australia
# 567085
# Australia
# 568145
# Australia
# 568687
# Australia
# 568695
# Australia
# 568708
# Australia
# ...
